# %%
import pandas as pd

df = pd.read_csv("./generated/atp_matches_2010.csv")
yas = df['surface']

yas.value_counts().sort_index().plot.bar(ylabel ='Number of Occurrences', xlabel = "Surface")
# Out:
# <AxesSubplot: xlabel='Surface', ylabel='Number of Occurrences'>

# %%
df = pd.read_csv("./generated/atp_matches_2011.csv")
yas = df['surface']

yas.value_counts().sort_index().plot.bar(ylabel ='Number of Occurrences', xlabel = "Surface")
# Out:
# <AxesSubplot: xlabel='Surface', ylabel='Number of Occurrences'>

# %%
df = pd.read_csv("./generated/atp_matches_2012.csv")
yas = df['surface']

yas.value_counts().sort_index().plot.bar(ylabel ='Number of Occurrences', xlabel = "Surface")
# Out:
# <AxesSubplot: xlabel='Surface', ylabel='Number of Occurrences'>
